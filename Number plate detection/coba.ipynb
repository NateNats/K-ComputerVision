# %%
import pandas as pd
import numpy as np
import easyocr
import cv2
import imutils
import ultralytics
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv2.imread('dataset/img.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
